# %% [markdown]
# 1. Accede a spotify con tu cuenta: https://developer.spotify.com/documentation/web-api
# 2. Ingresa al dashboard con tu cuenta https://developer.spotify.com/dashboard
# 3. Crea una app con una variante del nombre Fundamentos Big Data, explica que es un ejercicio de clase, la URL y URI son las mismas, elige una direccion de pagina web a la que tengas acceso
# 4. Copia el Client ID y Client Secret de la app que acabas de crear
# 5. Instalar la libreria de python para la api de spotify

# %%
#no necesario: pip install typing-extensions==3.10.0.0

# %%
# no necesario: pip install --upgrade spacy

# %% [markdown]
# Necesario instalar:

# %%
#pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#librerias necesarias para la conexion
import requests
import json

# %%
# Ingresa las claves de tu app en el Dashboard de spotify
# Ingresa las claves de tu app en el Dashboard de spotify
client_id = "#"
client_secret = "#"

# %%
# Iniciar el cliente de spotify
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Encontrar las mas populares

# %%
# Lista Top 50, encontrar las 10 mas escuchadas
top_tracks = sp.playlist_tracks('0bjJHQh5Vd3ko386LsCUk5', limit=9)

# %%
# Imprimir el nombre de las 10 mas escuchadas
for idx, track in enumerate(top_tracks['items']):
    track_name = track['track']['name']
    artist_name = track['track']['artists'][0]['name']
    print(f"{idx + 1}. {track_name} by {artist_name}")
# Out:
# 1. Riptide by Vance Joy
# 2. ily (i love you baby) (feat. Emilee) by Surf Mesa
# 3. Flowers by Miley Cyrus
# 4. greedy by Tate McRae
# 5. Fast Car by ItsLee
# 6. Cruel Summer by Taylor Swift
# 7. As It Was by Harry Styles
# 8. Calm Down (with Selena Gomez) by Rema
# 9. Bloom by Lucas Estrada

# %% [markdown]
# ### Encontrar playlists

# %%
# Buscar una playlist por su nombre
playlist_results = sp.search(q='Chill lounge coffee', type='playlist')

# %%
playlist_results
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=Chill+lounge+coffee&type=playlist&offset=0&limit=10',
#   'items': [{'collaborative': False,
#     'description': 'Coffe shop Music to enjoy in the mornings! Cafe Music - Bar lounge - Chill Vibes - Accustic Covers - Relax Vibes - Morning Vibes - Chillout - Work Playlist - Soft Music - Calm Songs - Sleep Music ',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/11nSleISOWGLboWVWPDuwB'},
#     'href': 'https://api.spotify.com/v1/playlists/11nSleISOWGLboWVWPDuwB',
#     'id': '11nSleISOWGLboWVWPDuwB',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb445f40e95e8cfbb64d1e7192',
#       'width': None}],
#     'name': 'Café Music 2023 ☕ Coffee Lounge Vibes',
#     'owner': {'display_name': 'LoudKult',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/43xzlwfo0tft7hn5r5e6dksrd'},
#      'href': 'https://api.spotify.com/v1/users/43xzlwfo0tft7hn5r5e6dksrd',
#      'id': '43xzlwfo0tft7hn5r5e6dksrd',
#      'type': 'user',
#      'uri': 'spotify:user:43xzlwfo0tft7hn5r5e6dksrd'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NTA4LDUxZTQ0NjdkM2FhZDc3ZTE1ZmZmZGM3NzBkN2VkNDJjOWU4MDgwNzA=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/11nSleISOWGLboWVWPDuwB/tracks',
#      'total': 211},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:11nSleISOWGLboWVWPDuwB'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/12LfKXJYnkzkyO8KmMJPOo'},
#     'href': 'https://api.spotify.com/v1/playlists/12LfKXJYnkzkyO8KmMJPOo',
#     'id': '12LfKXJYnkzkyO8KmMJPOo',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273044a5466dac00f7b3c570b99ab67616d0000b27370889b194f8cb62891309011ab67616d0000b27387182b0a619c6073e4473aa8ab67616d0000b273a7a72fa27131a7aa9048e738',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273044a5466dac00f7b3c570b99ab67616d0000b27370889b194f8cb62891309011ab67616d0000b27387182b0a619c6073e4473aa8ab67616d0000b273a7a72fa27131a7aa9048e738',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273044a5466dac00f7b3c570b99ab67616d0000b27370889b194f8cb62891309011ab67616d0000b27387182b0a619c6073e4473aa8ab67616d0000b273a7a72fa27131a7aa9048e738',
#       'width': 60}],
#     'name': 'ChillL',
#     'owner': {'display_name': 'Briiramirezz',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/12136732671'},
#      'href': 'https://api.spotify.com/v1/users/12136732671',
#      'id': '12136732671',
#      'type': 'user',
#      'uri': 'spotify:user:12136732671'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjA4LDc0ZTk2NzIwMjEyODJhNjRkYTEwYTBkZGIzZDlmMjg5NzBjMGM4OWY=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/12LfKXJYnkzkyO8KmMJPOo/tracks',
#      'total': 201},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:12LfKXJYnkzkyO8KmMJPOo'},
#    {'collaborative': False,
#     'description': 'Morning chill music - Music to relax too - Coffe happy songs - Beach Lounge - Happy Summer - Work playlist - Mood booster - Coffee Lounge -  Cafe Lounge ',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0bjJHQh5Vd3ko386LsCUk5'},
#     'href': 'https://api.spotify.com/v1/playlists/0bjJHQh5Vd3ko386LsCUk5',
#     'id': '0bjJHQh5Vd3ko386LsCUk5',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb6cd37c52f8a90ce2cd35b5fc',
#       'width': None}],
#     'name': 'Morning Music ☕ Chillout Vibes - Coffee Lounge',
#     'owner': {'display_name': 'LoudKult',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/43xzlwfo0tft7hn5r5e6dksrd'},
#      'href': 'https://api.spotify.com/v1/users/43xzlwfo0tft7hn5r5e6dksrd',
#      'id': '43xzlwfo0tft7hn5r5e6dksrd',
#      'type': 'user',
#      'uri': 'spotify:user:43xzlwfo0tft7hn5r5e6dksrd'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'ODIyLDVhOWRkZmQxMzMyMDRmYWZiNjNhY2NiYTdkZDM0MTE1NGNlMDc3ODE=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0bjJHQh5Vd3ko386LsCUk5/tracks',
#      'total': 211},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0bjJHQh5Vd3ko386LsCUk5'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7yOWbdcgRfreoil4EgY7Nn'},
#     'href': 'https://api.spotify.com/v1/playlists/7yOWbdcgRfreoil4EgY7Nn',
#     'id': '7yOWbdcgRfreoil4EgY7Nn',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbfc0195db197ef1121c4e3913',
#       'width': None}],
#     'name': 'Chill lofi type ',
#     'owner': {'display_name': 'Rattlehead',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/oliverbaseflug'},
#      'href': 'https://api.spotify.com/v1/users/oliverbaseflug',
#      'id': 'oliverbaseflug',
#      'type': 'user',
#      'uri': 'spotify:user:oliverbaseflug'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzY5LGUxNGJlZDlhNTY0NzE5M2NkYjIyM2NhZjg0MzIxOTljNzg1NTBkNmQ=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7yOWbdcgRfreoil4EgY7Nn/tracks',
#      'total': 69},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7yOWbdcgRfreoil4EgY7Nn'},
#    {'collaborative': False,
#     'description': 'Chill & Bumpy',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWVUxkQFrGCkK'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVUxkQFrGCkK',
#     'id': '37i9dQZF1DWVUxkQFrGCkK',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003986c59c636c839a72a9b0d62',
#       'width': None}],
#     'name': 'Umami',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwMjA0NjQ0MSwwMDAwMDAwMDQ5NDA1YTMzOWUyMTZiMmJkNzIzMDE1MWYxOWEzZTA2',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVUxkQFrGCkK/tracks',
#      'total': 216},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWVUxkQFrGCkK'},
#    {'collaborative': False,
#     'description': 'this is it',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3g2JGyJ0xWWBmS6V0o7FeK'},
#     'href': 'https://api.spotify.com/v1/playlists/3g2JGyJ0xWWBmS6V0o7FeK',
#     'id': '3g2JGyJ0xWWBmS6V0o7FeK',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb2f45d9a54736fe1367e8dd02',
#       'width': None}],
#     'name': 'chillo',
#     'owner': {'display_name': 'mɘtɘ',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/meddlmedde'},
#      'href': 'https://api.spotify.com/v1/users/meddlmedde',
#      'id': 'meddlmedde',
#      'type': 'user',
#      'uri': 'spotify:user:meddlmedde'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'OTg3LGI1ZDQwZDNhYThhZGMwZDdlMzIwZWQ1NTA5ZjU5MDFiMzNmMTgxNzc=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3g2JGyJ0xWWBmS6V0o7FeK/tracks',
#      'total': 255},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3g2JGyJ0xWWBmS6V0o7FeK'},
#    {'collaborative': False,
#     'description': 'Positive Vibes, Brazilian Beachside Beats, Lounge Bar Grooves, Coffee House &amp; Chill Out Music. ',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/5Z6AhELcmzaOcbiLGcQyu5'},
#     'href': 'https://api.spotify.com/v1/playlists/5Z6AhELcmzaOcbiLGcQyu5',
#     'id': '5Z6AhELcmzaOcbiLGcQyu5',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbafc35eae27d8610ea49e359b',
#       'width': None}],
#     'name': 'Lounge (Bar & Café)  ',
#     'owner': {'display_name': 'PMB Music',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/pmb-music'},
#      'href': 'https://api.spotify.com/v1/users/pmb-music',
#      'id': 'pmb-music',
#      'type': 'user',
#      'uri': 'spotify:user:pmb-music'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'ODM1LGY3YTNhODcyMzhjYzJkYTI2ZDM5Njc1YzdmMGYyMTIxZTkxYTJlNGI=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/5Z6AhELcmzaOcbiLGcQyu5/tracks',
#      'total': 265},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:5Z6AhELcmzaOcbiLGcQyu5'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6JdQjfISiHOHYKEi43lmMC'},
#     'href': 'https://api.spotify.com/v1/playlists/6JdQjfISiHOHYKEi43lmMC',
#     'id': '6JdQjfISiHOHYKEi43lmMC',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27328e12bc569f20d9f8ebff84cab67616d0000b273a47ee7a49c53ccdcb38dc874ab67616d0000b273b479faaba482002b6acc87abab67616d0000b273ff26bd277274b27f249cc638',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27328e12bc569f20d9f8ebff84cab67616d0000b273a47ee7a49c53ccdcb38dc874ab67616d0000b273b479faaba482002b6acc87abab67616d0000b273ff26bd277274b27f249cc638',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27328e12bc569f20d9f8ebff84cab67616d0000b273a47ee7a49c53ccdcb38dc874ab67616d0000b273b479faaba482002b6acc87abab67616d0000b273ff26bd277274b27f249cc638',
#       'width': 60}],
#     'name': 'CITY CAVE CHILL',
#     'owner': {'display_name': 'Bondi Junction',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31jjnjhtjsdgd6gm2g7nptcwkebi'},
#      'href': 'https://api.spotify.com/v1/users/31jjnjhtjsdgd6gm2g7nptcwkebi',
#      'id': '31jjnjhtjsdgd6gm2g7nptcwkebi',
#      'type': 'user',
#      'uri': 'spotify:user:31jjnjhtjsdgd6gm2g7nptcwkebi'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NDYsODFlMmEwYjUzY2ExMGE2ZWY2NzUxNmU4NzNhNTliN2IzNjJiOTQyMw==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6JdQjfISiHOHYKEi43lmMC/tracks',
#      'total': 45},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6JdQjfISiHOHYKEi43lmMC'},
#    {'collaborative': False,
#     'description': 'selection of chill instrumental hip-hop beats to relax, meditate, code and drink coffee to – including mellow lo-fi jazz vibes, smooth chill-hop, dope 90s old school boom-bap and lofi dinner lounge music. featuring flofilz, cookin soul, ... / updated weekly / IG: madmaxbeats_',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3G1pIa3dYHK4nIrQ3d3dpU'},
#     'href': 'https://api.spotify.com/v1/playlists/3G1pIa3dYHK4nIrQ3d3dpU',
#     'id': '3G1pIa3dYHK4nIrQ3d3dpU',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb579aa5b02b3462d8b8ba0b3d',
#       'width': None}],
#     'name': 'CHILL BEATS – jazz vibes / lo-fi / chillhop / instrumental hip hop / study beats / cafe lounge',
#     'owner': {'display_name': 'mädmäx',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/madmax_93'},
#      'href': 'https://api.spotify.com/v1/users/madmax_93',
#      'id': 'madmax_93',
#      'type': 'user',
#      'uri': 'spotify:user:madmax_93'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjU3NCw2MzlkM2FmODc5ODM5MmEyNmRiYTc1OTc2ZjU3OTI0ZjVmMDE3YjEy',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3G1pIa3dYHK4nIrQ3d3dpU/tracks',
#      'total': 300},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3G1pIa3dYHK4nIrQ3d3dpU'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3vzr6HAa6EIaW4YnAnX2vU'},
#     'href': 'https://api.spotify.com/v1/playlists/3vzr6HAa6EIaW4YnAnX2vU',
#     'id': '3vzr6HAa6EIaW4YnAnX2vU',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273121a9af58f3604f78dd68f6bab67616d0000b2739fb96f00ec7713368599ea8cab67616d0000b273d5800f8720e1714bce93cad7ab67616d0000b273f0b22473a87abf7907c258ba',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273121a9af58f3604f78dd68f6bab67616d0000b2739fb96f00ec7713368599ea8cab67616d0000b273d5800f8720e1714bce93cad7ab67616d0000b273f0b22473a87abf7907c258ba',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273121a9af58f3604f78dd68f6bab67616d0000b2739fb96f00ec7713368599ea8cab67616d0000b273d5800f8720e1714bce93cad7ab67616d0000b273f0b22473a87abf7907c258ba',
#       'width': 60}],
#     'name': 'Lofi chill',
#     'owner': {'display_name': 'jdvalencia63',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/jdvalencia63'},
#      'href': 'https://api.spotify.com/v1/users/jdvalencia63',
#      'id': 'jdvalencia63',
#      'type': 'user',
#      'uri': 'spotify:user:jdvalencia63'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NTksM2QxMWQ4ZjQ1NGE2ODU0YjNiZmI2OGZlNWMyMjQ3N2FlZjRiZWM3Mg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3vzr6HAa6EIaW4YnAnX2vU/tracks',
#      'total': 58},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3vzr6HAa6EIaW4YnAnX2vU'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Chill+lounge+coffee&type=playlist&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 398}}

# %%
# Extraer los IDs de las playlists  y las descripciones
if playlist_results and 'playlists' in playlist_results:
    playlists = playlist_results['playlists']['items']
    if playlists:
        playlist_id = playlists[1]['id']
        print(f"Playlist ID: {playlist_id}")
    else:
        print("No playlists found with that name.")
else:
    print("No playlist search results.")
# Out:
# Playlist ID: 12LfKXJYnkzkyO8KmMJPOo

# %%
playlist_name = '50 TOP Bolivia'
playlist_results = sp.search(q=playlist_name, type='playlist')

# %%
if playlist_results and 'playlists' in playlist_results:
    playlists = playlist_results['playlists']['items']
    if playlists:
        print(f"Found {len(playlists)} playlists with the name '{playlist_name}':")
        for idx, playlist in enumerate(playlists):
            playlist_id = playlist['id']
            playlist_description = playlist['description']
            print(f"Playlist {idx + 1} ID: {playlist_id}")
            print(f"Description: {playlist_description}\n")
    else:
        print("No playlists found with that name.")
else:
    print("No playlist search results.")
# Out:
# Found 10 playlists with the name '50 TOP Bolivia':
# Playlist 1 ID: 37i9dQZEVXbJqfMFK4d691
# Description: Your daily update of the most played tracks right now - Bolivia.
#
# Playlist 2 ID: 37i9dQZEVXbMDoHDwVN2tF
# Description: Your daily update of the most played tracks right now - Global.
#
# Playlist 3 ID: 2rqZ9qdGPvynwSsXYewi3N
# Description: Las canciones más actualizadas!
#
# Playlist 4 ID: 37i9dQZEVXbO3qyFxbkOE1
# Description: Your daily update of the most played tracks right now - Mexico.
#
# Playlist 5 ID: 5SS5OHukV2EKMwakNAjfUZ
# Description: Vive tu día escuchando nuestra playlist con todos los éxitos de Bolivia!  | Bolivia | Éxitos Bolivia | Top 50 Bolivia | Lo más sonado Bolivia | Top Hits Bolivia | Viral Bolivia
#
# Playlist 6 ID: 37i9dQZF1DXbOnyEG5dOWL
# Description: ¡Escucha los éxitos de hoy!
# Foto: Arcángel
#
# Playlist 7 ID: 3L0GTgyBzx3cITSPBqE5CE
# Description: The Top 50 tracks in Bolivia right now 🎯 Los 50 mejores éxitos del momento en Bolivia.
#
# Playlist 8 ID: 37i9dQZEVXbLZ52XmnySJg
# Description: Your daily update of the most played tracks right now - India.
#
# Playlist 9 ID: 36k0sqc44u7p0pq5auuvQd
# Description: | Los 50 más Virales | Reggaetón 2022 | Éxitos 2022 | Lo Más Nuevo 2022 | Reguetón 2022  | Lo más sonado | Música Nueva | Música variada | Música Top | Lo más Viral | Lo más Viral Tiktok | TikTok | TikTok Trends
#
# Playlist 10 ID: 2MGqkd7u2u87tLLFyzJ7DH
# Description: The Top 100 tracks in Bolivia right now 🎯 Los 100 mejores éxitos del momento en Bolivia.

# %% [markdown]
# #### Describir canciones

# %%
# Search for tracks by name
track_name = 'Me cuesta tanto olvidarte'
track_results = sp.search(q=track_name, type='track', limit=10)

# Extract the duration and artist from the search results
if track_results and 'tracks' in track_results:
    tracks = track_results['tracks']['items']
    if tracks:
        print(f"Found {len(tracks)} tracks with the name '{track_name}':")
        for idx, track in enumerate(tracks):
            track_name = track['name']
            track_duration = track['duration_ms']  # Duration in milliseconds
            track_artist = track['artists'][0]['name']
            
            # Convert duration from milliseconds to minutes and seconds
            duration_minutes = track_duration // 60000
            duration_seconds = (track_duration % 60000) // 1000
            
            print(f"Track {idx + 1} - {track_name}")
            print(f"Artist: {track_artist}")
            print(f"Duration: {duration_minutes}:{duration_seconds:02}\n")
    else:
        print("No tracks found with that name.")
else:
    print("No track search results.")
# Out:
# Found 10 tracks with the name 'Me cuesta tanto olvidarte':
# Track 1 - Me Cuesta Tanto Olvidarte
# Artist: Mecano
# Duration: 2:54
#
# Track 2 - Me Cuesta Tanto Olvidarte
# Artist: Los Ángeles Azules
# Duration: 2:44
#
# Track 3 - Me Cuesta Tanto Olvidarte
# Artist: Enrique Iglesias
# Duration: 3:34
#
# Track 4 - Me Cuesta
# Artist: Hermanos Espinoza
# Duration: 3:01
#
# Track 5 - Me Cuesta Tanto Olvidarte
# Artist: Adriana Ríos
# Duration: 2:53
#
# Track 6 - Me Cuesta Tanto Olvidarte
# Artist: Claire Delić
# Duration: 3:43
#
# Track 7 - Me Cuesta Olvidarla
# Artist: Skavy El Ángel Caído
# Duration: 3:12
#
# Track 8 - Me Cuesta Tanto Olvidarte
# Artist: Thalia
# Duration: 3:22
#
# Track 9 - Me Cuesta Tanto
# Artist: Los inquietos del vallenato
# Duration: 4:33
#
# Track 10 - Me cuesta tanto olvidarte
# Artist: Alex Ubago
# Duration: 2:27

# %% [markdown]
# #### Buscar las canciones de un artista

# %%
# Search for the artist by name
artist_name = 'Celine Dione'
artist_results = sp.search(q=artist_name, type='artist', limit=1)

# Extract the artist's ID from the search results
if artist_results and 'artists' in artist_results:
    artists = artist_results['artists']['items']
    if artists:
        artist_id = artists[0]['id']
        
        # Get the artist's albums
        artist_albums = sp.artist_albums(artist_id, album_type='album')
        
        # Extract and print the names of the artist's albums
        print(f"Albums by {artist_name}:")
        for album in artist_albums['items']:
            print(album['name'])
            
            # Get the tracks of each album
            album_tracks = sp.album_tracks(album['id'])
            
            # Print the tracks of the album
            for track in album_tracks['items']:
                print(f"  {track['name']}")
    else:
        print("No artists found with that name.")
else:
    print("No artist search results.")
# Out:
# Albums by Celine Dione:
# Love Again (Soundtrack from the Motion Picture)
#   Love Again
#   I'll Be
#   Waiting on You
#   Love of My Life
#   The Gift
#   It's All Coming Back to Me Now
#   Orpheus and Eurydice - Score from the Motion Picture "Love Again"
#   All By Myself
#   Where Does My Heart Beat Now
#   Celine Wisdom - Score from the Motion Picture "Love Again"
#   A New Day Has Come
#   Courage
#   That's the Way It Is
#   Love Takes Courage - Score from the Motion Picture "Love Again"
# Courage (Deluxe Edition)
#   Flying On My Own
#   Lovers Never Die
#   Falling In Love Again
#   Lying Down
#   Courage
#   Imperfections
#   Change My Mind
#   Say Yes
#   Nobody's Watching
#   The Chase
#   For The Lover That I Lost
#   Baby
#   I Will Be Stronger
#   How Did You Get Here
#   Look at Us Now
#   Perfect Goodbye
#   Best of All
#   Heart of Glass
#   Boundaries
#   The Hard Way
# Encore un soir (Deluxe Edition)
#   Plus qu'ailleurs
#   L'étoile
#   Ma faille
#   Encore un soir
#   Je nous veux
#   Les yeux au ciel
#   Si c'était à refaire
#   Ordinaire
#   Tu sauras
#   Toutes ces choses
#   Le bonheur en face
#   À la plus haute branche
#   À vous
#   Ma force
#   Trois heures vingt - Remastered
# Encore un soir
#   Plus qu'ailleurs
#   L'étoile
#   Ma faille
#   Encore un soir
#   Je nous veux
#   Les yeux au ciel
#   Si c'était à refaire
#   Ordinaire
#   Tu sauras
#   Toutes ces choses
#   Le bonheur en face
#   À la plus haute branche
# Céline... Une seule fois / Live 2013
#   Ce n'était qu'un rêve (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Dans un autre monde (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Parler à mon père (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   It's All Coming Back to Me Now / The Power of Love (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   On ne change pas (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Destin (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Qui peut vivre sans amour? (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Je crois toi (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   La mer et l'enfant (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Celle qui m'a tout appris (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Terre (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   J'irai où tu iras (Live in Quebec City) (with Jean-Marc Couture)
#   Bozo (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Je n'ai pas besoin d'amour (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   S'il suffisait d'aimer (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   L'amour existe encore (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   All by Myself (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Je sais pas (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Je danse dans ma tête / Des mots qui sonnent / Incognito (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Love Can Move Mountains / River Deep Mountain High (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   My Heart Will Go On (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Pour que tu m'aimes encore (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Loved Me Back to Life (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Le miracle (Live in Quebec City) - Live from Quebec City, Canada - July 2013
#   Tout l'or des hommes (Live at Bercy, 2013) - Live at Palais Omnisports de Paris-Bercy, Paris, France - 2013
#   Ziggy (Un garçon pas comme les autres) [Live at Bercy, 2013] - Live at Palais Omnisports de Paris-Bercy, Paris, France - 2013
#   Water and a Flame (Live at Bercy, 2013) - Live at Palais Omnisports de Paris-Bercy, Paris, France - 2013
#   Regarde-moi (Live at Bercy, 2013) - Live at Palais Omnisports de Paris-Bercy, Paris, France - 2013
# Loved Me Back to Life
#   Loved Me Back to Life
#   Somebody Loves Somebody
#   Incredible
#   Water and a Flame
#   Breakaway
#   Save Your Soul
#   Didn't Know Love
#   Thank You
#   Overjoyed (with Stevie Wonder)
#   Thankful
#   At Seventeen
#   Always Be Your Girl
#   Unfinished Songs
#   How Do You Keep the Music Playing
#   Lullabye (Goodnight, My Angel)
# Sans attendre
#   Parler à mon père
#   Le miracle
#   Qui peut vivre sans amour?
#   L'amour peut prendre froid (with Johnny Hallyday) - duo Johnny Hallyday
#   Attendre
#   Une chance qu'on s'a (with Jean-Pierre Ferland) - duo Jean-Pierre Ferland
#   La mer et l'enfant
#   Moi quand je pleure
#   Celle qui m'a tout appris
#   Je n'ai pas besoin d'amour
#   Si je n'ai rien de toi
#   Que toi au monde (en cours)
#   Tant de Temps (with Henri Salvador) - duo Henri Salvador
#   Les petits pieds de Léa
#   Ne me quitte pas
#   Les jours comme ça
# La Tournée Mondiale Taking Chances LE SPECTACLE
#   Ouverture - I Drove All Night - Live at Bell Centre, Montreal, Canada - 2008
#   I Drove All Night - Live at Bell Centre, Montreal, Canada - 2008
#   J'irai ou tu iras - Live at Bell Centre, Montreal, Canada - 2008
#   Destin - Live at Bell Centre, Montreal, Canada - 2008
#   Taking Chances - Live at Bell Centre, Montreal, Canada - 2008
#   Et s'il n'en restait qu'une (je serais celle-là) - Live at Bell Centre, Montreal, Canada - 2008
#   L'Amour existe encore - Live at Bell Centre, Montreal, Canada - 2008
#   Dans un autre monde - Live at Bell Centre, Montreal, Canada - 2008
#   All By Myself - Live at Bell Centre, Montreal, Canada - 2008
#   Je sais pas - Live at Bell Centre, Montreal, Canada - 2008
#   S'il suffisait d'aimer - Live at Bell Centre, Montreal, Canada - 2008
#   Alone - Live at Bell Centre, Montreal, Canada - 2008
#   Medley Soul - Live at Bell Centre, Montreal, Canada - 2008
#   It's A Man's Man's Man's World - Live at Bell Centre, Montreal, Canada - 2008
#   River Deep, Mountain High - Live at Bell Centre, Montreal, Canada - 2008
#   My Heart Will Go On - Live at Bell Centre, Montreal, Canada - 2008
#   Pour que tu m'aimes encore - Live at Bell Centre, Montreal, Canada - 2008
# Taking Chances World Tour THE CONCERT (Live)
#   Opening - I Drove All Night - Live at TD Garden, Boston, Massachusetts - 2008
#   I Drove All Night - Live at TD Garden, Boston, Massachusetts - 2008
#   The Power of Love - Live at TD Garden, Boston, Massachusetts - 2008
#   Taking Chances - Live at TD Garden, Boston, Massachusetts - 2008
#   It's All Coming Back To Me Now - Live at TD Garden, Boston, Massachusetts - 2008
#   Because You Loved Me (Love Theme from "Up Close And Personal") - Live at TD Garden, Boston, Massachusetts - 2008
#   To Love You More - Live at TD Garden, Boston, Massachusetts - 2008
#   New Mego's Flamenco - Live at TD Garden, Boston, Massachusetts - 2008
#   Eyes On Me - Live at TD Garden, Boston, Massachusetts - 2008
#   All By Myself - Live at TD Garden, Boston, Massachusetts - 2008
#   Shadow Of Love - Live at TD Garden, Boston, Massachusetts - 2008
#   Alone - Live at TD Garden, Boston, Massachusetts - 2008
#   My Love - Live at TD Garden, Boston, Massachusetts - 2008
#   The Prayer (virtual duet with Andrea Bocelli) - Live at TD Garden, Boston, Massachusetts - 2008
#   Soul Medley: Sex Machine / Soul Man / Lady Marmalade / Sir Duke / Respect / I Got The Feelin' / I Got You (I Feel Good) - Live at TD Garden, Boston, Massachusetts - 2008
#   It's A Man's Man's Man's World - Live at TD Garden, Boston, Massachusetts - 2008
#   Love Can Move Mountains - Live at TD Garden, Boston, Massachusetts - 2008
#   River Deep, Mountain High - Live at TD Garden, Boston, Massachusetts - 2008
#   My Heart Will Go On - Live at TD Garden, Boston, Massachusetts - 2008
# Taking Chances (Deluxe Edition)
#   Taking Chances
#   Alone
#   Eyes On Me
#   My Love
#   Shadow Of Love
#   Surprise Surprise
#   This Time
#   New Dawn
#   A Song For You
#   A World to Believe In
#   Can't Fight The Feelin'
#   I Got Nothin' Left
#   Right Next To The Right One
#   Fade Away
#   That's Just The Woman In Me
#   Skies Of L.A.
#   Immensité
#   Map To My Heart
#   Taking Chances - i-Soul Extended Remix
# D'elles
#   Et s'il n'en restait qu'une (je serais celle-là)
#   Immensité
#   A cause
#   Je cherche l'ombre
#   Les paradis
#   La diva
#   Femme comme chacune
#   Si j'étais quelqu'un
#   Je ne suis pas celle
#   Le temps qui compte
#   Lettre de George Sand à Alfred de Musset
#   On s'est aimé à cause
#   Berceuse
# Miracle
#   Miracle
#   Brahms' Lullaby
#   If I Could
#   Sleep Tight
#   What a Wonderful World
#   My Precious One
#   A Mother's Prayer
#   The First Time Ever I Saw Your Face
#   Baby Close Your Eyes
#   Come To me
#   Le loup, la biche et le chevalier (une chanson douce)
#   Beautiful Boy
#   In Some Small Way
# A New Day...Live In Las Vegas
#   Nature Boy - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   It's All Coming Back To Me Now - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   Because You Loved Me - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   I'm Alive - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   If I Could - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   At Last - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   Fever - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   I've Got the World on a String - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   Et je t'aime encore - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   I Wish - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   I Drove All Night - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   My Heart Will Go On (Love Theme from "Titanic") - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   What a Wonderful World - Live at The Colosseum at Caesars Palace, Las Vegas, Nevada - November 2003
#   You And I
#   Ain't Gonna Look The Other Way
#   Contre nature
# 1 fille & 4 types
#   Tout l'or des hommes
#   Apprends-moi
#   Le vol d'un ange
#   Ne bouge pas
#   Tu nages
#   Et je t'aime encore - French version
#   Retiens-moi
#   Je lui dirai
#   Mon homme
#   Rien n'est vraiment fini
#   Contre nature
#   Des milliers de baisers
# One Heart
#   I Drove All Night
#   Love Is All We Need
#   Faith
#   In His Touch
#   One Heart
#   Stand By Your Side
#   Naked
#   Sorry for Love - 2003 Version
#   Have You Ever Been In Love
#   Reveal
#   Coulda Woulda Shoulda
#   Forget Me Not
#   I Know What Love Is
#   Et je t'aime encore - English version
# A New Day Has Come
#   I'm Alive
#   Right In Front of You
#   Have You Ever Been In Love
#   Rain, Tax (It's Inevitable)
#   A New Day Has Come - Radio Remix
#   Ten Days
#   Goodbye's (The Saddest Word)
#   Prayer
#   I Surrender
#   At Last
#   Super Love
#   Sorry for Love
#   Aún existe amor - Spanish version of "L'amour existe encore"
#   The Greatest Reward
#   When the Wrong One Loves You Right
#   A New Day Has Come
#   Nature Boy
# Au Coeur Du Stade (Live)
#   Let's Talk About Love - Live at Stade de France, Paris, France - June 1999
#   Dans un autre monde - Live at Stade de France, Paris, France - June 1999
#   Je sais pas - Live at Stade de France, Paris, France - June 1999
#   Je crois toi - Live at Stade de France, Paris, France - June 1999
#   Terre - Live at Stade de France, Paris, France - June 1999
#   J'irai où tu iras - Live at Stade de France, Paris, France - June 1999
#   S'il Suffisait D'Aimer - Live at Stade de France, Paris, France - June 1999
#   On ne change pas - Live at Stade de France, Paris, France - June 1999
#   Medley acoustique - Live at Stade de France, Paris, France - June 1999
#   Pour que tu m'aimes encore - Live at Stade de France, Paris, France - June 1999
#   My Heart Will Go On (Love Theme from "Titanic") - Live at Stade de France, Paris, France - June 1999
# These are Special Times
#   O Holy Night
#   Don't Save It All for Christmas Day
#   Blue Christmas
#   Another Year Has Gone By
#   The Magic Of Christmas Day (God Bless Us Everyone)
#   Ave Maria
#   Adeste Fideles (O Come All Ye Faithful)
#   The Christmas Song (Chestnuts Roasting on an Open Fire)
#   The Prayer
#   Brahms' Lullaby
#   Christmas Eve
#   These Are the Special Times
#   Happy Xmas (War Is Over)
#   Feliz Navidad
#   Les Cloches du Hameau
#   I Met an Angel (on Christmas Day)
# S'il Suffisait D'aimer
#   Je crois toi
#   Zora sourit
#   On ne change pas
#   Je chanterai
#   Terre
#   En attendant ses pas
#   Papillon
#   L'abandon
#   Dans un autre monde
#   Sur le même bateau
#   Tous les blues sont écrits pour toi
#   S'il suffisait d'aimer
# Let's Talk About Love
#   The Reason
#   Immortality (feat. Bee Gees)
#   Treat Her Like a Lady
#   Why Oh Why
#   Love Is On the Way
#   Tell Him (Duet with Barbra Streisand)
#   Amar haciendo el amor
#   When I Need You
#   Miles to Go (Before I Sleep)
#   Us
#   Just a Little Bit of Love
#   My Heart Will Go On - Love Theme from "Titanic"
#   Where Is the Love
#   Be the Man (On This Night) - English Version
#   I Hate You Then I Love You (Duet with Luciano Pavarotti)
#   Let's Talk About Love

# %% [markdown]
# Encontrar el ID del album

# %%
# Nombre del album
album_name = 'Wish You Were Here'

# Search for the album by name
results = sp.search(q=album_name, type='album', limit=1)

# Extract and print the album ID from the search results
if results and 'albums' in results:
    albums = results['albums']['items']
    if albums:
        album_id = albums[0]['id']
        print(f"Album ID for '{album_name}': {album_id}")
    else:
        print(f"No album found with the name '{album_name}'.")
else:
    print("No search results.")
# Out:
# Album ID for 'Wish You Were Here': 0bCAjiUamIFqKJsekOYuRw

# %%
# Buscar los detalles del album
album_metadata = sp.album(album_id)

# %%
# Imprimir las claves 
print("Keys (field names) of album metadata:")
for key in album_metadata.keys():
    print(key)
# Out:
# Keys (field names) of album metadata:
# album_type
# artists
# available_markets
# copyrights
# external_ids
# external_urls
# genres
# href
# id
# images
# label
# name
# popularity
# release_date
# release_date_precision
# total_tracks
# tracks
# type
# uri

# %%
# Extract and print the release date
release_date = album_metadata['release_date']
print(f"Release Date: {release_date}")
# Out:
# Release Date: 1975-09-12

# %%
#El valor de popularidad proporciona una indicación de cuán popular es el álbum entre los usuarios de Spotify. La puntuación
#de popularidad varía de 0 a 100, y los valores más altos indican una mayor popularidad.
album_metadata['popularity']
# Out:
# 73

# %% [markdown]
# # Análisis de Sentimiento de Texto

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Descargamos el lexicon  VADER de NLTK para analisis de sentimiento de texto
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\sharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Buscamos al artista deseado
artist_name = 'Pink Floyd'
artist_results = sp.search(q=artist_name, type='artist', limit=1)

# %%
# extraemos su ID
if artist_results and 'artists' in artist_results:
    artists = artist_results['artists']['items']
    if artists:
        artist_id = artists[0]['id']
        
        # Get the artist's albums
        artist_albums = sp.artist_albums(artist_id, album_type='album')
        
        # Extract and analyze sentiment of the names of the artist's albums
        print(f"Sentiment analysis of albums by {artist_name}:")
        sid = SentimentIntensityAnalyzer()
        for album in artist_albums['items']:
            album_name = album['name']
            sentiment_scores = sid.polarity_scores(album_name)
            
            print(f"Album: {album_name}")
            print(f"Sentiment scores: {sentiment_scores}")
            
            sentiment_label = "Positive" if sentiment_scores['compound'] > 0.2 else "Negative" if sentiment_scores['compound'] < -0.2 else "Neutral"
            print(f"Sentiment: {sentiment_label}\n")
            
            # Get the tracks of each album
            album_tracks = sp.album_tracks(album['id'])
            
            # Print the names of the tracks
            print(f"Tracks in {album_name}:")
            for track in album_tracks['items']:
                print(f"  {track['name']}")
    else:
        print("No hay artistas con ese nombre.")
else:
    print("No hay resultados para ese artista.")
# Out:
# Sentiment analysis of albums by Pink Floyd:
# Album: The Dark Side Of The Moon (Live at Wembley 1974) [2023 Master]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in The Dark Side Of The Moon (Live at Wembley 1974) [2023 Master]:
#   Speak to Me - Live at Wembley 1974 - 2023 Master
#   Breathe (In the Air) - Live at Wembley 1974 - 2023 Master
#   On the Run - Live at Wembley 1974 - 2023 Master
#   Time - Live at Wembley 1974 - 2023 Master
#   The Great Gig in the Sky - Live at Wembley 1974 - 2023 Master
#   Money - Live at Wembley 1974 - 2023 Master
#   Us and Them - Live at Wembley 1974 - 2023 Master
#   Any Colour You Like - Live at Wembley 1974 - 2023 Master
#   Brain Damage - Live at Wembley 1974 - 2023 Master
#   Eclipse - Live at Wembley 1974 - 2023 Master
# Album: Live at Knebworth 1990
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in Live at Knebworth 1990:
#   Shine On You Crazy Diamond (Parts 1-5) - Live at Knebworth 1990
#   The Great Gig In the Sky - Live at Knebworth 1990
#   Wish You Were Here - Live at Knebworth 1990
#   Sorrow - Live at Knebworth 1990
#   Money - Live at Knebworth 1990
#   Comfortably Numb - Live at Knebworth 1990
#   Run Like Hell - Live at Knebworth 1990
# Album: Delicate Sound of Thunder (2019 Remix) [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.0516}
# Sentiment: Neutral
#
# Tracks in Delicate Sound of Thunder (2019 Remix) [Live]:
#   Shine On You Crazy Diamond (Parts 1-5) - 2019 remix [Live]
#   Signs of Life - 2019 remix [Live]
#   Learning to Fly - 2019 remix [Live]
#   Yet Another Movie - 2019 remix [Live]
#   Round and Around - 2019 remix [Live]
#   A New Machine Part 1 - 2019 remix [Live]
#   Terminal Frost - 2019 remix [Live]
#   A New Machine Part 2 - 2019 remix [Live]
#   Sorrow - 2019 remix [Live]
#   The Dogs of War - 2019 remix [Live]
#   On the Turning Away - 2019 remix [Live]
#   One of These Days - 2019 remix [Live]
#   Time - 2019 remix [Live]
#   On the Run - 2019 remix [Live]
#   The Great Gig In the Sky - 2019 remix [Live]
#   Wish You Were Here - 2019 remix [Live]
#   Welcome to the Machine - 2019 remix [Live]
#   Us and Them - 2019 remix [Live]
#   Money - 2019 remix [Live]
#   Another Brick In the Wall, Part 2 - 2019 remix [Live]
#   Comfortably Numb - 2019 remix [Live]
#   One Slip - 2019 remix [Live]
#   Run Like Hell - 2019 remix [Live]
# Album: The Endless River
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in The Endless River:
#   Side 1, Pt. 1: Things Left Unsaid
#   Side 1, Pt. 2: It's What We Do
#   Side 1, Pt. 3: Ebb And Flow
#   Side 2, Pt. 1: Sum
#   Side 2, Pt. 2: Skins
#   Side 2, Pt. 3: Unsung
#   Side 2, Pt. 4: Anisina
#   Side 3, Pt. 1: The Lost Art of Conversation
#   Side 3, Pt. 2: On Noodle Street
#   Side 3, Pt. 3: Night Light
#   Side 3, Pt. 4: Allons-y (1)
#   Side 3, Pt. 5: Autumn '68
#   Side 3, Pt. 6: Allons-y (2)
#   Side 3, Pt. 7: Talkin' Hawkin'
#   Side 4, Pt. 1: Calling
#   Side 4, Pt. 2: Eyes To Pearls
#   Side 4, Pt. 3: Surfacing
#   Side 4, Pt. 4: Louder Than Words
#   TBS9
#   TBS14
#   Nervana
# Album: Pulse (Live)
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in Pulse (Live):
#   Shine On You Crazy Diamond (Pts. 1-5, 7) - Live
#   Astronomy Domine - Live
#   What Do You Want from Me - Live
#   Learning to Fly - Live
#   Keep Talking - Live
#   Coming Back to Life - Live
#   Hey You - Live
#   A Great Day for Freedom - Live
#   Sorrow - Live
#   High Hopes - Live
#   Another Brick in the Wall, (Pt. 2) - Live
#   One of These Days - Live
#   Speak to Me - Live
#   Breathe (In the Air) - Live
#   On the Run - Live
#   Time - Live
#   The Great Gig in the Sky - Live
#   Money - Live
#   Us and Them - Live
#   Any Colour You Like - Live
#   Brain Damage - Live
#   Eclipse - Live
#   Wish You Were Here - Live
#   Comfortably Numb - Live
#   Run Like Hell - Live
# Album: The Division Bell
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in The Division Bell:
#   Cluster One
#   What Do You Want from Me
#   Poles Apart
#   Marooned
#   A Great Day for Freedom
#   Wearing the Inside Out
#   Take It Back
#   Coming Back to Life
#   Keep Talking
#   Lost for Words
#   High Hopes
# Album: Delicate Sound of Thunder (Live)
# Sentiment scores: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.0516}
# Sentiment: Neutral
#
# Tracks in Delicate Sound of Thunder (Live):
#   Shine On You Crazy Diamond - Live
#   Learning to Fly - Live
#   Yet Another Movie - Live
#   Round and Around - Live
#   Sorrow - Live
#   The Dogs of War - Live
#   On the Turning Away - Live
#   One of These Days - Live
#   Time - Live
#   Wish You Were Here - Live
#   Us and Them - Live
#   Money - Live
#   Another Brick in the Wall, Pt. 2 - Live
#   Comfortably Numb - Live
#   Run Like Hell - Live
# Album: A Momentary Lapse of Reason
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in A Momentary Lapse of Reason:
#   Signs of Life
#   Learning to Fly
#   The Dogs of War
#   One Slip
#   On the Turning Away
#   Yet Another Movie
#   Round and Around
#   A New Machine, Pt. 1
#   Terminal Frost
#   A New Machine, Pt. 2
#   Sorrow
# Album: A Momentary Lapse of Reason (2019 Remix)
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in A Momentary Lapse of Reason (2019 Remix):
#   Signs of Life - Remix 2019
#   Learning to Fly - Remix 2019
#   The Dogs of War - Remix 2019
#   One Slip - Remix 2019
#   On the Turning Away - Remix 2019
#   Yet Another Movie - Remix 2019
#   Round and Around - Remix 2019
#   A New Machine Part 1 - Remix 2019
#   Terminal Frost - Remix 2019
#   A New Machine Part 2 - Remix 2019
#   Sorrow - Remix 2019
# Album: The Final Cut
# Sentiment scores: {'neg': 0.512, 'neu': 0.488, 'pos': 0.0, 'compound': -0.2732}
# Sentiment: Negative
#
# Tracks in The Final Cut:
#   The Post War Dream
#   Your Possible Pasts
#   One of the Few
#   When the Tigers Broke Free
#   The Hero's Return
#   The Gunner's Dream
#   Paranoid Eyes
#   Get Your Filthy Hands Off My Desert
#   The Fletcher Memorial Home
#   Southampton Dock
#   The Final Cut
#   Not Now John
#   Two Suns in the Sunset
# Album: The Wall
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in The Wall:
#   In the Flesh?
#   The Thin Ice
#   Another Brick in the Wall, Pt. 1
#   The Happiest Days of Our Lives
#   Another Brick in the Wall, Pt. 2
#   Mother
#   Goodbye Blue Sky
#   Empty Spaces
#   Young Lust
#   One of My Turns
#   Don't Leave Me Now
#   Another Brick in the Wall, Pt. 3
#   Goodbye Cruel World
#   Hey You
#   Is There Anybody Out There?
#   Nobody Home
#   Vera
#   Bring the Boys Back Home
#   Comfortably Numb
#   The Show Must Go On
#   In the Flesh
#   Run Like Hell
#   Waiting for the Worms
#   Stop
#   The Trial
#   Outside the Wall
# Album: Animals
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in Animals:
#   Pigs on the Wing 1
#   Dogs
#   Pigs (Three Different Ones)
#   Sheep
#   Pigs on the Wing 2
# Album: Animals (2018 Remix)
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in Animals (2018 Remix):
#   Pigs on the Wing 1 - 2018 Remix
#   Dogs - 2018 Remix
#   Pigs (Three Different Ones) - 2018 Remix
#   Sheep - 2018 Remix
#   Pigs on the Wing 2 - 2018 Remix
# Album: Wish You Were Here
# Sentiment scores: {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
# Sentiment: Positive
#
# Tracks in Wish You Were Here:
#   Shine On You Crazy Diamond (Pts. 1-5)
#   Welcome to the Machine
#   Have a Cigar
#   Wish You Were Here
#   Shine On You Crazy Diamond (Pts. 6-9)
# Album: The Dark Side Of The Moon (50th Anniversary) [2023 Remaster]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in The Dark Side Of The Moon (50th Anniversary) [2023 Remaster]:
#   Speak to Me - 2023 Remaster
#   Breathe (In the Air) - 2023 Remaster
#   On the Run - 2023 Remaster
#   Time - 2023 Remaster
#   The Great Gig in the Sky - 2023 Remaster
#   Money - 2023 Remaster
#   Us and Them - 2023 Remaster
#   Any Colour You Like - 2023 Remaster
#   Brain Damage - 2023 Remaster
#   Eclipse - 2023 Remaster
# Album: The Dark Side of the Moon
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in The Dark Side of the Moon:
#   Speak to Me
#   Breathe (In the Air)
#   On the Run
#   Time
#   The Great Gig in the Sky
#   Money
#   Us and Them
#   Any Colour You Like
#   Brain Damage
#   Eclipse
# Album: Obscured by Clouds
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in Obscured by Clouds:
#   Obscured by Clouds
#   When You're In
#   Burning Bridges
#   The Gold It's in the...
#   Wot's...Uh the Deal
#   Mudmen
#   Childhood's End
#   Free Four
#   Stay
#   Absolutely Curtains
# Album: Meddle
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in Meddle:
#   One of These Days
#   A Pillow of Winds
#   Fearless
#   San Tropez
#   Seamus
#   Echoes
# Album: Atom Heart Mother
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in Atom Heart Mother:
#   Atom Heart Mother
#   If
#   Summer '68
#   Fat Old Sun
#   Alan's Psychedelic Breakfast
# Album: Ummagumma
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Tracks in Ummagumma:
#   Astronomy Domine - Live
#   Careful with That Axe, Eugene - Live
#   Set the Controls for the Heart of the Sun - Live
#   A Saucerful of Secrets - Live
#   Sysyphus, Pt. 1
#   Sysyphus, Pt. 2
#   Sysyphus, Pt. 3
#   Sysyphus, Pt. 4
#   Grantchester Meadows
#   Several Species of Small Furry Animals Gathered Together in a Cave and Grooving with a Pict
#   The Narrow Way, Pt. 1
#   The Narrow Way, Pt. 2
#   The Narrow Way, Pt. 3
#   The Grand Vizier's Garden Party, Pt. 1 (Entrance)
#   The Grand Vizier's Garden Party, Pt. 2 (Entertainment)
#   The Grand Vizier's Garden Party, Pt. 3 (Exit)

# %%
# Search for the artist by name
artist_name = 'Pink Floyd'
artist_results = sp.search(q=artist_name, type='artist', limit=1)

# Extract the artist's ID from the search results
if artist_results and 'artists' in artist_results:
    artists = artist_results['artists']['items']
    if artists:
        artist_id = artists[0]['id']
        
        # Get the artist's albums
        artist_albums = sp.artist_albums(artist_id, album_type='album')
        
        # Initialize the sentiment analyzer
        sid = SentimentIntensityAnalyzer()
        
        print(f"Sentiment analysis of track titles in albums by {artist_name}:\n")
        
        # iteramos
        for album in artist_albums['items']:
            album_name = album['name']
            print(f"Album: {album_name}\n")
            
            # Get the tracks of each album
            album_tracks = sp.album_tracks(album['id'])
            
            # Iterate through tracks in the album
            for idx, track in enumerate(album_tracks['items']):
                track_name = track['name']
                
                # Perform sentiment analysis on track title
                sentiment_scores = sid.polarity_scores(track_name)
                
                sentiment_label = "Positive" if sentiment_scores['compound'] > 0.5 else "Negative" if sentiment_scores['compound'] < 0 else "Neutral"
                
                print(f"Track {idx + 1}: {track_name}")
                print(f"Sentiment scores: {sentiment_scores}")
                print(f"Sentiment: {sentiment_label}\n")
    else:
        print("No artists found with that name.")
else:
    print("No artist search results.")
# Out:
# Sentiment analysis of track titles in albums by Pink Floyd:
#
# Album: The Dark Side Of The Moon (Live at Wembley 1974) [2023 Master]
#
# Track 1: Speak to Me - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Breathe (In the Air) - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: On the Run - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Time - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: The Great Gig in the Sky - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.6249}
# Sentiment: Positive
#
# Track 6: Money - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Us and Them - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: Any Colour You Like - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'compound': 0.3612}
# Sentiment: Neutral
#
# Track 9: Brain Damage - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.314, 'neu': 0.686, 'pos': 0.0, 'compound': -0.4939}
# Sentiment: Negative
#
# Track 10: Eclipse - Live at Wembley 1974 - 2023 Master
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: Live at Knebworth 1990
#
# Track 1: Shine On You Crazy Diamond (Parts 1-5) - Live at Knebworth 1990
# Sentiment scores: {'neg': 0.174, 'neu': 0.652, 'pos': 0.174, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: The Great Gig In the Sky - Live at Knebworth 1990
# Sentiment scores: {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'compound': 0.6249}
# Sentiment: Positive
#
# Track 3: Wish You Were Here - Live at Knebworth 1990
# Sentiment scores: {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019}
# Sentiment: Neutral
#
# Track 4: Sorrow - Live at Knebworth 1990
# Sentiment scores: {'neg': 0.459, 'neu': 0.541, 'pos': 0.0, 'compound': -0.5267}
# Sentiment: Negative
#
# Track 5: Money - Live at Knebworth 1990
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: Comfortably Numb - Live at Knebworth 1990
# Sentiment scores: {'neg': 0.261, 'neu': 0.435, 'pos': 0.304, 'compound': 0.1027}
# Sentiment: Neutral
#
# Track 7: Run Like Hell - Live at Knebworth 1990
# Sentiment scores: {'neg': 0.38, 'neu': 0.413, 'pos': 0.207, 'compound': -0.4767}
# Sentiment: Negative
#
# Album: Delicate Sound of Thunder (2019 Remix) [Live]
#
# Track 1: Shine On You Crazy Diamond (Parts 1-5) - 2019 remix [Live]
# Sentiment scores: {'neg': 0.187, 'neu': 0.625, 'pos': 0.187, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Signs of Life - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: Learning to Fly - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Yet Another Movie - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Round and Around - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: A New Machine Part 1 - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Terminal Frost - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: A New Machine Part 2 - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 9: Sorrow - 2019 remix [Live]
# Sentiment scores: {'neg': 0.531, 'neu': 0.469, 'pos': 0.0, 'compound': -0.5267}
# Sentiment: Negative
#
# Track 10: The Dogs of War - 2019 remix [Live]
# Sentiment scores: {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'compound': -0.5994}
# Sentiment: Negative
#
# Track 11: On the Turning Away - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 12: One of These Days - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 13: Time - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 14: On the Run - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 15: The Great Gig In the Sky - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 0.661, 'pos': 0.339, 'compound': 0.6249}
# Sentiment: Positive
#
# Track 16: Wish You Were Here - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 0.69, 'pos': 0.31, 'compound': 0.4019}
# Sentiment: Neutral
#
# Track 17: Welcome to the Machine - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.4588}
# Sentiment: Neutral
#
# Track 18: Us and Them - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 19: Money - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 20: Another Brick In the Wall, Part 2 - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 21: Comfortably Numb - 2019 remix [Live]
# Sentiment scores: {'neg': 0.293, 'neu': 0.366, 'pos': 0.341, 'compound': 0.1027}
# Sentiment: Neutral
#
# Track 22: One Slip - 2019 remix [Live]
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 23: Run Like Hell - 2019 remix [Live]
# Sentiment scores: {'neg': 0.414, 'neu': 0.36, 'pos': 0.225, 'compound': -0.4767}
# Sentiment: Negative
#
# Album: The Endless River
#
# Track 1: Side 1, Pt. 1: Things Left Unsaid
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Side 1, Pt. 2: It's What We Do
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: Side 1, Pt. 3: Ebb And Flow
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Side 2, Pt. 1: Sum
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Side 2, Pt. 2: Skins
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: Side 2, Pt. 3: Unsung
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Side 2, Pt. 4: Anisina
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: Side 3, Pt. 1: The Lost Art of Conversation
# Sentiment scores: {'neg': 0.223, 'neu': 0.777, 'pos': 0.0, 'compound': -0.3182}
# Sentiment: Negative
#
# Track 9: Side 3, Pt. 2: On Noodle Street
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 10: Side 3, Pt. 3: Night Light
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 11: Side 3, Pt. 4: Allons-y (1)
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 12: Side 3, Pt. 5: Autumn '68
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 13: Side 3, Pt. 6: Allons-y (2)
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 14: Side 3, Pt. 7: Talkin' Hawkin'
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 15: Side 4, Pt. 1: Calling
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 16: Side 4, Pt. 2: Eyes To Pearls
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 17: Side 4, Pt. 3: Surfacing
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 18: Side 4, Pt. 4: Louder Than Words
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 19: TBS9
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 20: TBS14
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 21: Nervana
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: Pulse (Live)
#
# Track 1: Shine On You Crazy Diamond (Pts. 1-5, 7) - Live
# Sentiment scores: {'neg': 0.203, 'neu': 0.593, 'pos': 0.203, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Astronomy Domine - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: What Do You Want from Me - Live
# Sentiment scores: {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.0772}
# Sentiment: Neutral
#
# Track 4: Learning to Fly - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Keep Talking - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: Coming Back to Life - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Hey You - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: A Great Day for Freedom - Live
# Sentiment scores: {'neg': 0.0, 'neu': 0.265, 'pos': 0.735, 'compound': 0.8519}
# Sentiment: Positive
#
# Track 9: Sorrow - Live
# Sentiment scores: {'neg': 0.773, 'neu': 0.227, 'pos': 0.0, 'compound': -0.5267}
# Sentiment: Negative
#
# Track 10: High Hopes - Live
# Sentiment scores: {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.4215}
# Sentiment: Neutral
#
# Track 11: Another Brick in the Wall, (Pt. 2) - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 12: One of These Days - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 13: Speak to Me - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 14: Breathe (In the Air) - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 15: On the Run - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 16: Time - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 17: The Great Gig in the Sky - Live
# Sentiment scores: {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.6249}
# Sentiment: Positive
#
# Track 18: Money - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 19: Us and Them - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 20: Any Colour You Like - Live
# Sentiment scores: {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.3612}
# Sentiment: Neutral
#
# Track 21: Brain Damage - Live
# Sentiment scores: {'neg': 0.615, 'neu': 0.385, 'pos': 0.0, 'compound': -0.4939}
# Sentiment: Negative
#
# Track 22: Eclipse - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 23: Wish You Were Here - Live
# Sentiment scores: {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
# Sentiment: Neutral
#
# Track 24: Comfortably Numb - Live
# Sentiment scores: {'neg': 0.387, 'neu': 0.161, 'pos': 0.452, 'compound': 0.1027}
# Sentiment: Neutral
#
# Track 25: Run Like Hell - Live
# Sentiment scores: {'neg': 0.505, 'neu': 0.22, 'pos': 0.275, 'compound': -0.4767}
# Sentiment: Negative
#
# Album: The Division Bell
#
# Track 1: Cluster One
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: What Do You Want from Me
# Sentiment scores: {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.0772}
# Sentiment: Neutral
#
# Track 3: Poles Apart
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Marooned
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: A Great Day for Freedom
# Sentiment scores: {'neg': 0.0, 'neu': 0.194, 'pos': 0.806, 'compound': 0.8519}
# Sentiment: Positive
#
# Track 6: Wearing the Inside Out
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Take It Back
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: Coming Back to Life
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 9: Keep Talking
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 10: Lost for Words
# Sentiment scores: {'neg': 0.535, 'neu': 0.465, 'pos': 0.0, 'compound': -0.3182}
# Sentiment: Negative
#
# Track 11: High Hopes
# Sentiment scores: {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215}
# Sentiment: Neutral
#
# Album: Delicate Sound of Thunder (Live)
#
# Track 1: Shine On You Crazy Diamond - Live
# Sentiment scores: {'neg': 0.273, 'neu': 0.455, 'pos': 0.273, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Learning to Fly - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: Yet Another Movie - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Round and Around - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Sorrow - Live
# Sentiment scores: {'neg': 0.773, 'neu': 0.227, 'pos': 0.0, 'compound': -0.5267}
# Sentiment: Negative
#
# Track 6: The Dogs of War - Live
# Sentiment scores: {'neg': 0.494, 'neu': 0.506, 'pos': 0.0, 'compound': -0.5994}
# Sentiment: Negative
#
# Track 7: On the Turning Away - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: One of These Days - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 9: Time - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 10: Wish You Were Here - Live
# Sentiment scores: {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
# Sentiment: Neutral
#
# Track 11: Us and Them - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 12: Money - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 13: Another Brick in the Wall, Pt. 2 - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 14: Comfortably Numb - Live
# Sentiment scores: {'neg': 0.387, 'neu': 0.161, 'pos': 0.452, 'compound': 0.1027}
# Sentiment: Neutral
#
# Track 15: Run Like Hell - Live
# Sentiment scores: {'neg': 0.505, 'neu': 0.22, 'pos': 0.275, 'compound': -0.4767}
# Sentiment: Negative
#
# Album: A Momentary Lapse of Reason
#
# Track 1: Signs of Life
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Learning to Fly
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: The Dogs of War
# Sentiment scores: {'neg': 0.565, 'neu': 0.435, 'pos': 0.0, 'compound': -0.5994}
# Sentiment: Negative
#
# Track 4: One Slip
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: On the Turning Away
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: Yet Another Movie
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Round and Around
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: A New Machine, Pt. 1
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 9: Terminal Frost
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 10: A New Machine, Pt. 2
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 11: Sorrow
# Sentiment scores: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5267}
# Sentiment: Negative
#
# Album: A Momentary Lapse of Reason (2019 Remix)
#
# Track 1: Signs of Life - Remix 2019
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Learning to Fly - Remix 2019
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: The Dogs of War - Remix 2019
# Sentiment scores: {'neg': 0.438, 'neu': 0.562, 'pos': 0.0, 'compound': -0.5994}
# Sentiment: Negative
#
# Track 4: One Slip - Remix 2019
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: On the Turning Away - Remix 2019
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: Yet Another Movie - Remix 2019
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Round and Around - Remix 2019
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: A New Machine Part 1 - Remix 2019
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 9: Terminal Frost - Remix 2019
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 10: A New Machine Part 2 - Remix 2019
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 11: Sorrow - Remix 2019
# Sentiment scores: {'neg': 0.63, 'neu': 0.37, 'pos': 0.0, 'compound': -0.5267}
# Sentiment: Negative
#
# Album: The Final Cut
#
# Track 1: The Post War Dream
# Sentiment scores: {'neg': 0.494, 'neu': 0.253, 'pos': 0.253, 'compound': -0.4404}
# Sentiment: Negative
#
# Track 2: Your Possible Pasts
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: One of the Few
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: When the Tigers Broke Free
# Sentiment scores: {'neg': 0.308, 'neu': 0.33, 'pos': 0.363, 'compound': 0.128}
# Sentiment: Neutral
#
# Track 5: The Hero's Return
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: The Gunner's Dream
# Sentiment scores: {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.25}
# Sentiment: Neutral
#
# Track 7: Paranoid Eyes
# Sentiment scores: {'neg': 0.667, 'neu': 0.333, 'pos': 0.0, 'compound': -0.25}
# Sentiment: Negative
#
# Track 8: Get Your Filthy Hands Off My Desert
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 9: The Fletcher Memorial Home
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 10: Southampton Dock
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 11: The Final Cut
# Sentiment scores: {'neg': 0.512, 'neu': 0.488, 'pos': 0.0, 'compound': -0.2732}
# Sentiment: Negative
#
# Track 12: Not Now John
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 13: Two Suns in the Sunset
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: The Wall
#
# Track 1: In the Flesh?
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: The Thin Ice
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: Another Brick in the Wall, Pt. 1
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: The Happiest Days of Our Lives
# Sentiment scores: {'neg': 0.0, 'neu': 0.543, 'pos': 0.457, 'compound': 0.6369}
# Sentiment: Positive
#
# Track 5: Another Brick in the Wall, Pt. 2
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: Mother
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Goodbye Blue Sky
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: Empty Spaces
# Sentiment scores: {'neg': 0.643, 'neu': 0.357, 'pos': 0.0, 'compound': -0.2023}
# Sentiment: Negative
#
# Track 9: Young Lust
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 10: One of My Turns
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 11: Don't Leave Me Now
# Sentiment scores: {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'compound': 0.0382}
# Sentiment: Neutral
#
# Track 12: Another Brick in the Wall, Pt. 3
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 13: Goodbye Cruel World
# Sentiment scores: {'neg': 0.655, 'neu': 0.345, 'pos': 0.0, 'compound': -0.5859}
# Sentiment: Negative
#
# Track 14: Hey You
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 15: Is There Anybody Out There?
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 16: Nobody Home
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 17: Vera
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 18: Bring the Boys Back Home
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 19: Comfortably Numb
# Sentiment scores: {'neg': 0.462, 'neu': 0.0, 'pos': 0.538, 'compound': 0.1027}
# Sentiment: Neutral
#
# Track 20: The Show Must Go On
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 21: In the Flesh
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 22: Run Like Hell
# Sentiment scores: {'neg': 0.568, 'neu': 0.123, 'pos': 0.309, 'compound': -0.4767}
# Sentiment: Negative
#
# Track 23: Waiting for the Worms
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 24: Stop
# Sentiment scores: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.296}
# Sentiment: Negative
#
# Track 25: The Trial
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 26: Outside the Wall
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: Animals
#
# Track 1: Pigs on the Wing 1
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Dogs
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: Pigs (Three Different Ones)
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Sheep
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Pigs on the Wing 2
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: Animals (2018 Remix)
#
# Track 1: Pigs on the Wing 1 - 2018 Remix
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Dogs - 2018 Remix
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: Pigs (Three Different Ones) - 2018 Remix
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Sheep - 2018 Remix
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Pigs on the Wing 2 - 2018 Remix
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: Wish You Were Here
#
# Track 1: Shine On You Crazy Diamond (Pts. 1-5)
# Sentiment scores: {'neg': 0.245, 'neu': 0.51, 'pos': 0.245, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Welcome to the Machine
# Sentiment scores: {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}
# Sentiment: Neutral
#
# Track 3: Have a Cigar
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Wish You Were Here
# Sentiment scores: {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
# Sentiment: Neutral
#
# Track 5: Shine On You Crazy Diamond (Pts. 6-9)
# Sentiment scores: {'neg': 0.245, 'neu': 0.51, 'pos': 0.245, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: The Dark Side Of The Moon (50th Anniversary) [2023 Remaster]
#
# Track 1: Speak to Me - 2023 Remaster
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Breathe (In the Air) - 2023 Remaster
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: On the Run - 2023 Remaster
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Time - 2023 Remaster
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: The Great Gig in the Sky - 2023 Remaster
# Sentiment scores: {'neg': 0.0, 'neu': 0.631, 'pos': 0.369, 'compound': 0.6249}
# Sentiment: Positive
#
# Track 6: Money - 2023 Remaster
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Us and Them - 2023 Remaster
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: Any Colour You Like - 2023 Remaster
# Sentiment scores: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.3612}
# Sentiment: Neutral
#
# Track 9: Brain Damage - 2023 Remaster
# Sentiment scores: {'neg': 0.516, 'neu': 0.484, 'pos': 0.0, 'compound': -0.4939}
# Sentiment: Negative
#
# Track 10: Eclipse - 2023 Remaster
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: The Dark Side of the Moon
#
# Track 1: Speak to Me
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Breathe (In the Air)
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: On the Run
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Time
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: The Great Gig in the Sky
# Sentiment scores: {'neg': 0.0, 'neu': 0.549, 'pos': 0.451, 'compound': 0.6249}
# Sentiment: Positive
#
# Track 6: Money
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Us and Them
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: Any Colour You Like
# Sentiment scores: {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.3612}
# Sentiment: Neutral
#
# Track 9: Brain Damage
# Sentiment scores: {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'compound': -0.4939}
# Sentiment: Negative
#
# Track 10: Eclipse
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: Obscured by Clouds
#
# Track 1: Obscured by Clouds
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: When You're In
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: Burning Bridges
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: The Gold It's in the...
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Wot's...Uh the Deal
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: Mudmen
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Childhood's End
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: Free Four
# Sentiment scores: {'neg': 0.0, 'neu': 0.233, 'pos': 0.767, 'compound': 0.5106}
# Sentiment: Positive
#
# Track 9: Stay
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 10: Absolutely Curtains
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: Meddle
#
# Track 1: One of These Days
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: A Pillow of Winds
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: Fearless
# Sentiment scores: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4404}
# Sentiment: Neutral
#
# Track 4: San Tropez
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Seamus
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: Echoes
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: Atom Heart Mother
#
# Track 1: Atom Heart Mother
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: If
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 3: Summer '68
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: Fat Old Sun
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Alan's Psychedelic Breakfast
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Album: Ummagumma
#
# Track 1: Astronomy Domine - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 2: Careful with That Axe, Eugene - Live
# Sentiment scores: {'neg': 0.2, 'neu': 0.571, 'pos': 0.229, 'compound': 0.0516}
# Sentiment: Neutral
#
# Track 3: Set the Controls for the Heart of the Sun - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 4: A Saucerful of Secrets - Live
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 5: Sysyphus, Pt. 1
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 6: Sysyphus, Pt. 2
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 7: Sysyphus, Pt. 3
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 8: Sysyphus, Pt. 4
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 9: Grantchester Meadows
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 10: Several Species of Small Furry Animals Gathered Together in a Cave and Grooving with a Pict
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 11: The Narrow Way, Pt. 1
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 12: The Narrow Way, Pt. 2
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 13: The Narrow Way, Pt. 3
# Sentiment scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Sentiment: Neutral
#
# Track 14: The Grand Vizier's Garden Party, Pt. 1 (Entrance)
# Sentiment scores: {'neg': 0.0, 'neu': 0.467, 'pos': 0.533, 'compound': 0.6908}
# Sentiment: Positive
#
# Track 15: The Grand Vizier's Garden Party, Pt. 2 (Entertainment)
# Sentiment scores: {'neg': 0.0, 'neu': 0.467, 'pos': 0.533, 'compound': 0.6908}
# Sentiment: Positive
#
# Track 16: The Grand Vizier's Garden Party, Pt. 3 (Exit)
# Sentiment scores: {'neg': 0.0, 'neu': 0.467, 'pos': 0.533, 'compound': 0.6908}
# Sentiment: Positive

# %%
import pandas as pd

# %%
# Buscar al artista por su nombre
nombre_artista = 'Mana'
resultados_artista = sp.search(q=nombre_artista, type='artist', limit=1)

# Extraer el ID del artista de los resultados de búsqueda
if resultados_artista and 'artists' in resultados_artista:
    artistas = resultados_artista['artists']['items']
    if artistas:
        id_artista = artistas[0]['id']
        
        # Obtener los álbumes del artista
        albums_artista = sp.artist_albums(id_artista, album_type='album')
        
        # Inicializar el analizador de sentimiento
        sid = SentimentIntensityAnalyzer()
        
        # Crear una lista para almacenar los datos de las canciones
        datos_canciones = []
        
        # Iterar a través de los álbumes
        for album in albums_artista['items']:
            nombre_album = album['name']
            
            # Obtener las canciones de cada álbum
            canciones_album = sp.album_tracks(album['id'])
            
            # Iterar a través de las canciones del álbum
            for cancion in canciones_album['items']:
                titulo_cancion = cancion['name']
                
                # Realizar el análisis de sentimiento en el título de la canción
                puntuaciones_sentimiento = sid.polarity_scores(titulo_cancion)
                
                etiqueta_sentimiento = "Positivo" if puntuaciones_sentimiento['compound'] > 0 else "Negativo" if puntuaciones_sentimiento['compound'] < 0 else "Neutral"
                
                # Agregar los datos de la canción a la lista
                datos_canciones.append({
                    'Título de la Canción': titulo_cancion,
                    'Puntuación Compuesta': puntuaciones_sentimiento['compound'],
                    'Sentimiento': etiqueta_sentimiento
                })

        # Crear un DataFrame a partir de los datos de las canciones
        df = pd.DataFrame(datos_canciones)
        
        # Imprimir el DataFrame
        print(df)
    else:
        print("No se encontraron artistas con ese nombre.")
else:
    print("No hay resultados de búsqueda de artistas.")
# Out:
#                          Título de la Canción  Puntuación Compuesta  \
# 0                            Adicto a Tu Amor                0.6124
# 1                          La Cama Incendiada                0.0000
# 2                                  La Prisión                0.0000
# 3                                      Ironía                0.0000
# 4                                   Peligrosa                0.0000
# ..                                        ...                   ...
# 289        Estoy Agotado - 2020 Remasterizado                0.0000
# 290  Perdido en Un Barco - 2020 Remasterizado                0.0000
# 291       La Puerta Azul - 2020 Remasterizado                0.0000
# 292                 Maeo - 2020 Remasterizado                0.0000
# 293      No Me Mires Así - 2020 Remasterizado               -0.2960
#
#     Sentimiento
# 0      Positivo
# 1       Neutral
# 2       Neutral
# 3       Neutral
# 4       Neutral
# ..          ...
# 289     Neutral
# 290     Neutral
# 291     Neutral
# 292     Neutral
# 293    Negativo
#
# [294 rows x 3 columns]

# %%
df
# Out:
#                          Título de la Canción  Puntuación Compuesta  \
# 0                            Adicto a Tu Amor                0.6124
# 1                          La Cama Incendiada                0.0000
# 2                                  La Prisión                0.0000
# 3                                      Ironía                0.0000
# 4                                   Peligrosa                0.0000
# ..                                        ...                   ...
# 289        Estoy Agotado - 2020 Remasterizado                0.0000
# 290  Perdido en Un Barco - 2020 Remasterizado                0.0000
# 291       La Puerta Azul - 2020 Remasterizado                0.0000
# 292                 Maeo - 2020 Remasterizado                0.0000
# 293      No Me Mires Así - 2020 Remasterizado               -0.2960
#
#     Sentimiento
# 0      Positivo
# 1       Neutral
# 2       Neutral
# 3       Neutral
# 4       Neutral
# ..          ...
# 289     Neutral
# 290     Neutral
# 291     Neutral
# 292     Neutral
# 293    Negativo
#
# [294 rows x 3 columns]
